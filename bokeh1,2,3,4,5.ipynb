# %%
#question 1

from bokeh.plotting import figure, show
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(x)
p = figure(title="Sine Wave", x_axis_label='x', y_axis_label='sin(x)')
p.line(x, y, line_width=2)
show(p)
# Out:
#   <div id="d15eb333-ff22-4966-bd3b-1496328a8a61" data-root-id="p1261" style="display: contents;"></div>

# %%
# question 2

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np
import pandas as pd
output_notebook()
np.random.seed(42)
data = {
    'x': np.random.rand(50) * 100,
    'y': np.random.rand(50) * 100,
    'sizes': np.random.randint(10, 30, 50),
    'colors': np.random.randint(1, 256, 50)  # For color mapping
}
df = pd.DataFrame(data)
p = figure(title="Random Scatter Plot", x_axis_label="X", y_axis_label="Y")
p.scatter('x', 'y', size='sizes', color='colors', source=df, fill_alpha=0.6, legend_label="Random Points")
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c74b0f27-4ae8-45fb-b967-7e71df7bc83c">Loading BokehJS ...</span>
#     </div>
#   <div id="bd48a522-e743-4219-b039-7df3cecc561e" data-root-id="p1412" style="display: contents;"></div>

# %%
# question 3

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.models import ColumnDataSource

output_notebook()
fruits = ['Apples', 'Oranges', 'Bananas', 'Pears']
counts = [20, 25, 30, 35]
source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))
p = figure(x_range=fruits, title="Fruit Counts", x_axis_label="Fruits", y_axis_label="Counts")
p.vbar(x='fruits', top='counts', width=0.5, source=source, legend_field="fruits",
       fill_color=factor_cmap('fruits', palette=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99'], factors=fruits))
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c47c084d-d363-4220-b7e1-c78e07582fc2">Loading BokehJS ...</span>
#     </div>
#   <div id="a31f5bc4-494a-4185-a734-0a4974b6639e" data-root-id="p1364" style="display: contents;"></div>

# %%
# question 4

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

output_notebook()
data_hist = np.random.randn(1000)
hist, edges = np.histogram(data_hist, bins=30)
p = figure(title="Histogram", x_axis_label="Value", y_axis_label="Frequency")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], fill_color="navy", line_color="white", alpha=0.7)
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d84b1913-9ab1-452f-9859-8d3d53a3d585">Loading BokehJS ...</span>
#     </div>
#   <div id="a859f578-b3f8-49ba-b5c0-c924c1ec293a" data-root-id="p1466" style="display: contents;"></div>
