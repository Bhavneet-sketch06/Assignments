# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
values=np.where(categories=='A',np.random.normal(10,5,100),np.where(categories=='B',np.random.normal(15,5,100),np.random.normal(20,5,100)))
categories=np.random.choice(['A','B','C'],size=100)
data=pd.DataFrame({'Category':categories,'Value':values})
data
sns.boxplot(x='Category',y='Value',data=data)
plt.title('Distribution of Numerical values across categories')
plt.show()
